# %%
import pandas as pd
import requests
import yaml
import io
import zipfile

from concurrent.futures import ThreadPoolExecutor


HEADERS = {
        "User-Agent": (
            "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4)"
            "AppleWebKit/537.36 (KHTML, like Gecko)"
            "Chrome/83.0.4103.97 Safari/537.36"
        )
    }


def check_url(url):
    """Test whether a url contains a valid zip file"""
    
    try:
        r = requests.get(url, headers=HEADERS)
        r.raise_for_status()
    except requests.exceptions.HTTPError as err:
        return f"HTTP error: {r.status_code}"
    except UnicodeError:
        return "Misformatted url"
        
    try:
        z = zipfile.ZipFile(io.BytesIO(r.content))
        #z.testzip()
    except zipfile.BadZipFile:
        return f"failed to unzip"
    
    return "success"

# %%
agency_data_url = (
    "https://raw.githubusercontent.com"
    "/cal-itp/data-infra/gtfs-list-tasks"
    "/airflow/data/agencies.yml"
)

r = requests.get(agency_data_url)
agencies_yml = yaml.safe_load(io.StringIO(r.text))

agencies = pd.DataFrame.from_dict(agencies_yml, orient = "index")

# %% [markdown]
# ## Agencies missing ids

# %%
agencies[lambda d: d.itp_id.isna()]
# Out:
#                                          agency_name  \
# altamont-corridor-express  Altamont Corridor Express
# banning-pass-transit            Banning Pass Transit
# calaveras-transit                  Calaveras Transit
# clean-air-express                  Clean Air Express
# cloverdale-transit                Cloverdale Transit
#
#                                                            gtfs_schedule_url  \
# altamont-corridor-express  [https://transitfeeds.com/p/altamont-corridor-...
# banning-pass-transit       [http://data.trilliumtransit.com/gtfs/banning-...
# calaveras-transit          [http://data.trilliumtransit.com/gtfs/calavera...
# clean-air-express          [http://www.cleanairexpress.com/GTFS7.24%COVID...
# cloverdale-transit         [http://data.trilliumtransit.com/gtfs/sonomaco...
#
#                            itp_id
# altamont-corridor-express     NaN
# banning-pass-transit          NaN
# calaveras-transit             NaN
# clean-air-express             NaN
# cloverdale-transit            NaN

# %% [markdown]
# ## Agencies not returning zip files

# %%
from concurrent import futures

agencies_long = agencies.explode("gtfs_schedule_url")

with ThreadPoolExecutor(max_workers = 8) as executor:
    agencies_long["status"] = list(executor.map(check_url, agencies_long.gtfs_schedule_url))

# %%
pd.set_option("display.max_colwidth", 99)
    
(agencies_long
  .loc[lambda d: d.status != "success"]
  .loc[:, ["agency_name", "status", "gtfs_schedule_url", "itp_id"]]
  .sort_values(["status", "agency_name"])
)
# Out:
#                                                                              agency_name  \
# ac-transit                                                                    AC Transit
# b-line                                                                            B-Line
# clean-air-express                                                      Clean Air Express
# culver-citybus                                                            Culver CityBus
# dinuba-area-regional-transit-                              Dinuba Area Regional Transit
# grapeline                                                                      Grapeline
# long-beach-transit                                                    Long Beach Transit
# manteca-transit                                                          Manteca Transit
# menlo-park-shuttles                                                  Menlo Park Shuttles
# paso-express                                                                Paso Express
# slo-transit                                                                  SLO Transit
# san-luis-obispo-regional-transit-authority    San Luis Obispo Regional Transit Authority
# santa-clara-valley-transportation-authority  Santa Clara Valley Transportation Authority
# south-county-area-transit                                      South County Area Transit
# tri-delta-transit                                                      Tri Delta Transit
# foothill-transit                                                        Foothill Transit
# gold-country-stage                                                    Gold Country Stage
# metro                                                                              Metro
# metro                                                                              Metro
# tri-valley-wheels                                                      Tri-Valley Wheels
# tulare-county-area-transit                                    Tulare County Area Transit
# e-tran                                                                            e-Tran
#
#                                                        status  \
# ac-transit                                    HTTP error: 401
# b-line                                        HTTP error: 404
# clean-air-express                             HTTP error: 404
# culver-citybus                                HTTP error: 404
# dinuba-area-regional-transit-                 HTTP error: 404
# grapeline                                     HTTP error: 404
# long-beach-transit                            HTTP error: 404
# manteca-transit                               HTTP error: 404
# menlo-park-shuttles                           HTTP error: 404
# paso-express                                  HTTP error: 404
# slo-transit                                   HTTP error: 404
# san-luis-obispo-regional-transit-authority    HTTP error: 404
# santa-clara-valley-transportation-authority   HTTP error: 404
# south-county-area-transit                     HTTP error: 404
# tri-delta-transit                            Misformatted url
# foothill-transit                              failed to unzip
# gold-country-stage                            failed to unzip
# metro                                         failed to unzip
# metro                                         failed to unzip
# tri-valley-wheels                             failed to unzip
# tulare-county-area-transit                    failed to unzip
# e-tran                                        failed to unzip
#
#                                                                                                                               gtfs_schedule_url  \
# ac-transit                                                      https://api.actransit.org/transit/gtfs/current?token=2512B8179D2DC44895CDDC6D42
# b-line                                                                                http://www.blinetransit.com/documents/google_transit.zip
# clean-air-express                                                                 http://www.cleanairexpress.com/GTFS7.24%COVID-19%CAE%GTFS.zip
# culver-citybus                                                                              https://www.culvercity.org/home/showdocument?id=169
# dinuba-area-regional-transit-                https://tularecog.org/tcag/data-gis-modeling/gis-project-and-data/gtfs-data-as-of-june-19-/dart...
# grapeline                                                                      http://www.mjcaction.com/MJC_GTFS_Public/lodi_google_transit.zip
# long-beach-transit                                                   https://lbtransit.box.com/shared/static/aoyeskwmsa9g7pyg78q3xuiolgqe4f.zip
# manteca-transit                                                    https://www.ci.manteca.ca.us/mantecatransit/googletransit/google_transit.zip
# menlo-park-shuttles                                                          https://www.menlopark.org/DocumentCenter/View/73/google_transitzip
# paso-express                                 http://app.mecatran.com/urb/ws/feed/c2ZT1zbGcmFuc2O2NsaWVudD1zZWxmO2V4cGlyZ7dHlwZT1ndGZzO2tlezZ...
# slo-transit                                  http://app.mecatran.com/urb/ws/feed/c2ZT1zbGcmFuc2O2NsaWVudD1zZWxmO2V4cGlyZ7dHlwZT1ndGZzO2tlezZ...
# san-luis-obispo-regional-transit-authority   http://app.mecatran.com/urb/ws/feed/c2ZT1zbGcmFuc2O2NsaWVudD1zZWxmO2V4cGlyZ7dHlwZT1ndGZzO2tlezZ...
# santa-clara-valley-transportation-authority                                   http://www.vta.org/sfc/servlet.shepherd/document/download6901NUea
# south-county-area-transit                    http://app.mecatran.com/urb/ws/feed/c2ZT1zbGcmFuc2O2NsaWVudD1zZWxmO2V4cGlyZ7dHlwZT1ndGZzO2tlezZ...
# tri-delta-transit                                                                              http://.232.147.132/rtt/public/utility/gtfs.aspx
# foothill-transit                                                                     http://foothilltransit.org/about/developer-resources/gtfs/
# gold-country-stage                                                                  http://data.trilliumtransit.com/gtfs/goldcountrystage-ca-us
# metro                                                                                                        https://gitlab.com/LACMTA/gtfs_bus
# metro                                                                                                       https://gitlab.com/LACMTA/gtfs_rail
# tri-valley-wheels                                                                                   https://www.wheelsbus.com/about/developers/
# tulare-county-area-transit                                                                 http://data.trilliumtransit.com/gtfs/tcat-flex-ca-us
# e-tran                                       https://share.elkgrovecity.org/messages/tpLyuetXMvzjM8oongDM5C/attachments/LbeTBVJuC2Eh3QPKIH6k...
#
#                                              itp_id
# ac-transit                                      4.0
# b-line                                         48.0
# clean-air-express                               NaN
# culver-citybus                                 87.0
# dinuba-area-regional-transit-                  93.0
# grapeline                                     168.0
# long-beach-transit                              1.0
# manteca-transit                               192.0
# menlo-park-shuttles                           199.0
# paso-express                                  244.0
# slo-transit                                   287.0
# san-luis-obispo-regional-transit-authority    289.0
# santa-clara-valley-transportation-authority   294.0
# south-county-area-transit                     388.0
# tri-delta-transit                             336.0
# foothill-transit                              112.0
# gold-country-stage                            221.0
# metro                                         182.0
# metro                                         182.0
# tri-valley-wheels                             167.0
# tulare-county-area-transit                    346.0
# e-tran                                          5.0
